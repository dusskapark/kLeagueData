# %% [markdown]
# 먼저, 주피터 노트북에서 웹 크롤링을 위한 파이썬 라이브러리인 BeautifulSoup, requests, 그리고 Selenium을 설치해야 합니다.

# %%
# %pip install beautifulsoup4 requests selenium lxml openpyxl
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (4.12.2)
# Requirement already satisfied: requests in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (2.31.0)
# Requirement already satisfied: selenium in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (4.11.2)
# Requirement already satisfied: lxml in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (4.9.3)
# Requirement already satisfied: openpyxl in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from beautifulsoup4) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from requests) (2023.5.7)
# Requirement already satisfied: trio~=0.17 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from selenium) (0.22.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from selenium) (0.10.3)
# Requirement already satisfied: et-xmlfile in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: attrs>=20.1.0 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: wsproto>=0.14 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from urllib3<3,>=1.21.1->requests) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/jude.park/Sites/venv-metal/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 그런 다음, 아래의 코드를 실행하여 웹드라이버를 설정합니다. 웹드라이버는 웹사이트를 자동으로 탐색하기 위해 사용됩니다. 이 예에서는 Chrome 웹드라이버를 사용하겠습니다. 웹드라이버를 사용하려면 해당 브라우저의 웹드라이버를 설치해야 합니다.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import pandas as pd

# 웹드라이버를 설정합니다. (여기서는 Chrome을 사용합니다.)
# 웹드라이버의 경로를 자신의 시스템에 맞게 설정해주세요.
options = Options()
options.page_load_strategy = 'eager'
driver = webdriver.Chrome(options=options)

# 웹사이트에 접속합니다.
driver.get('https://data.kleague.com')

# Find frameset element and get its children
frames = driver.find_elements("tag name", 'frame')

for frame in frames:
    if 'https://portal.kleague.com' in frame.get_attribute('src'):
        # redirect the browser to the frame url
        driver.get(frame.get_attribute('src'))
    else:
        # do nothing
        pass

# %% [markdown]
# onclick 속성에서 데이터를 추출하는 함수를 포함한 코드입니다. 사이트 구조상 onClick에서 데이터를 자주 추출해야함.

# %%
import re

def extract_onclick_data(onclick):
    if "moveMainFrameMcPlayer" in onclick:
        match = re.search(r"moveMainFrameMcPlayer\('(.+?)','(.+?)','(.+?)'\)", onclick)
        if match:
            return dict(zip(['menuCd', 'playerId', 'teamId'], match.groups()))
    elif "moveMainFrame" in onclick:
        match = re.search(r"moveMainFrame\('(.+?)'\)", onclick)
        if match:
            return {'menuCd': match.group(1)}
    return {}

# %%
# JavaScript를 실행하여 페이지를 이동합니다.
# driver.execute_script("moveMainFrame('0011')")
driver.execute_script("moveMainFrame('0415')")

# %%
# 페이지의 HTML을 가져옵니다.
html = driver.page_source

# BeautifulSoup 객체를 생성합니다.
soup = BeautifulSoup(html, 'html.parser')


# 특정 form 안에 있는 모든 테이블을 찾아 데이터를 스크랩핑합니다.
form = soup.find('form', {'id': 'frm'})
table_data = []
if form is not None:
    tables = form.find_all('table')
    for table in tables:
        # Get column names from thead
        column_names = [col.text for col in table.thead.find_all('th')]
        # Get all rows in the table
        rows = table.find_all('tr')
        row_data = []
        for row in rows:
            # Get all columns in the row
            cols = row.find_all('td')
            # Get onclick attribute value
            onclick = row.get('onclick')
            # Append the onclick value to the row data if it exists
            cols_data = dict(zip(column_names, [col.text for col in cols]))
            if onclick is not None:
                cols_data.update(extract_onclick_data(onclick))
            row_data.append(cols_data)
        table_data.append(pd.DataFrame(row_data))

# 데이터를 출력합니다.
for data in table_data:
    print(data)

# Export data to excel
with pd.ExcelWriter('kl_data.xlsx') as writer:
    for i, data in enumerate(table_data):
        data.to_excel(writer, sheet_name=f'Sheet{i+1}')
# Out:
#       소속 클럽   등번   성명      키   몸무게        생년월일 menuCd  playerId teamId
# 0       NaN  NaN  NaN    NaN   NaN         NaN    NaN       NaN    NaN
# 1      강원FC   25  김정호  184Cm  82Kg  1998/04/07   0416  20170124    K21
# 2      강원FC    1  유상훈  194Cm  84Kg  1989/05/25   0416  20110094    K21
# 3      강원FC   31  이광연  184Cm  85Kg  1999/09/11   0416  20190058    K21
# 4      강원FC   41  조민규  193Cm  87Kg  2003/04/30   0416  20230068    K21
# ..      ...  ...  ...    ...   ...         ...    ...       ...    ...
# 95  충북 청주FC   25  정현호  196Cm  85Kg  2004/11/26   0416  20230204    K37
# 96  포항 스틸러스    1  윤평국  189Cm  85Kg  1992/02/08   0416  20130151    K03
# 97  포항 스틸러스   32  이승환  187Cm  78Kg  2003/04/05   0416  20220160    K03
# 98  포항 스틸러스   41  조성훈  189Cm  85Kg  1998/04/21   0416  20190122    K03
# 99  포항 스틸러스   21  황인재  187Cm  73Kg  1994/04/22   0416  20160079    K03
#
# [100 rows x 9 columns]
#        소속 클럽   등번   성명      키   몸무게        생년월일 menuCd  playerId teamId
# 0        NaN  NaN  NaN    NaN   NaN         NaN    NaN       NaN    NaN
# 1       강원FC   74  강투지  190Cm  83Kg  1998/12/04   0416  20230308    K21
# 2       강원FC   42  권석주  178Cm  63Kg  2003/06/12   0416  20220065    K21
# 3       강원FC   38  김기환  176Cm  75Kg  2000/01/01   0416  20210113    K21
# 4       강원FC    2  김영빈  184Cm  79Kg  1991/09/20   0416  20140143    K21
# ..       ...  ...  ...    ...   ...         ...    ...       ...    ...
# 319  포항 스틸러스   13  신원철  175Cm  65Kg  2000/04/02   0416  20230038    K03
# 320  포항 스틸러스    2  심상민  172Cm  70Kg  1993/05/21   0416  20140066    K03
# 321  포항 스틸러스   34  이규백  186Cm  80Kg  2004/02/10   0416  20220193    K03
# 322  포항 스틸러스   55  최현웅  188Cm  80Kg  2003/10/09   0416  20220080    K03
# 323  포항 스틸러스   45  하창래  188Cm  82Kg  1994/10/16   0416  20170173    K03
#
# [324 rows x 9 columns]
#        소속 클럽   등번    성명      키   몸무게        생년월일 menuCd  playerId teamId
# 0        NaN  NaN   NaN    NaN   NaN         NaN    NaN       NaN    NaN
# 1       강원FC   13   강지훈  177Cm  64Kg  1997/01/06   0416  20180108    K21
# 2       강원FC   32   고민석  177Cm  65Kg  2000/12/12   0416  20230066    K21
# 3       강원FC   14   김대우  179Cm  80Kg  2000/12/02   0416  20210115    K21
# 4       강원FC   37   김현규  178Cm  63Kg  2001/07/12   0416  20220059    K21
# ..       ...  ...   ...    ...   ...         ...    ...       ...    ...
# 256  포항 스틸러스   17   신광훈  178Cm  73Kg  1987/03/18   0416  20060066    K03
# 257  포항 스틸러스    8  오베르단  175Cm  69Kg  1995/07/30   0416  20230043    K03
# 258  포항 스틸러스   19   윤민호  170Cm  64Kg  1999/10/17   0416  20220159    K03
# 259  포항 스틸러스   26   조재훈  178Cm  65Kg  2003/06/29   0416  20210309    K03
# 260  포항 스틸러스   16   한찬희  181Cm  78Kg  1997/03/17   0416  20160065    K03
#
# [261 rows x 9 columns]
#        소속 클럽   등번    성명      키   몸무게        생년월일 menuCd  playerId teamId
# 0        NaN  NaN   NaN    NaN   NaN         NaN    NaN       NaN    NaN
# 1       강원FC   63  가브리엘  187Cm  76Kg  2000/01/20   0416  20230333    K21
# 2       강원FC   11   갈레고  177Cm  71Kg  1997/04/04   0416  20220353    K21
# 3       강원FC   10   김대원  171Cm  65Kg  1997/02/10   0416  20160098    K21
# 4       강원FC   43   김해승  184Cm  80Kg  2003/02/06   0416  20220063    K21
# ..       ...  ...   ...    ...   ...         ...    ...       ...    ...
# 248  포항 스틸러스   30   윤재운  178Cm  73Kg  2002/04/01   0416  20230042    K03
# 249  포항 스틸러스   33   이호재  191Cm  85Kg  2000/10/14   0416  20210161    K03
# 250  포항 스틸러스   27   정재희  174Cm  70Kg  1994/04/28   0416  20160178    K03
# 251  포항 스틸러스    9    제카  192Cm  83Kg  1997/03/06   0416  20220294    K03
# 252  포항 스틸러스   37   홍윤상  176Cm  72Kg  2002/03/19   0416  20230332    K03
#
# [253 rows x 9 columns]

# %% [markdown]
# 선수 이름을 검색하여 해당 선수의 playerId와 teamId를 찾고, 이 정보를 사용하여 페이지를 이동시키는 코드를 추가

# %%
# Search for a specific player
player_name = "김주찬"  # replace with the name of the player you are looking for
for data in table_data:
    player_data = data[data['성명'] == player_name]
    if not player_data.empty:
        player_id = player_data['playerId'].values[0]
        team_id = player_data['teamId'].values[0]
        # Move to the page with the player's details
        driver.execute_script(f"moveMainFrameMcPlayer('0416', '{player_id}', '{team_id}')")
        break

# %%
import pandas as pd

# Execute JavaScript to get the value of resultDataSet
result_data_set = driver.execute_script("return resultDataSet;")

# Check if resultDataSet is a list
if isinstance(result_data_set, list):
    print(f"resultDataSet contains {len(result_data_set)} objects.")
    for i, obj in enumerate(result_data_set):
        # Convert the object to a DataFrame
        df = pd.DataFrame(obj)
        # Print the DataFrame
        print(f"Object {i+1}:")
        print(df)
else:
    print(f"resultDataSet is not a list. It is a {type(result_data_set)}.")

# Export data to excel with name of player_name as sheet name
with pd.ExcelWriter('kl_player_data.xlsx') as writer:
    for i, obj in enumerate(result_data_set):
        # Convert the object to a DataFrame
        df = pd.DataFrame(obj)
        df.to_excel(writer, sheet_name=f"{player_name}_{i+1}", index=False)
# Out:
# resultDataSet contains 7 objects.
# Object 1:
#    Team_S_Name Team_id
# 0           강원     K21
# 1           광주     K22
# 2           대구     K17
# 3           대전     K10
# 4           서울     K09
# 5           수원     K02
# 6         수원FC     K29
# 7           울산     K01
# 8           인천     K18
# 9           전북     K05
# 10          제주     K04
# 11          포항     K03
# Object 2:
#    PLAYER_ID   game_date  game_id game_time  meet_seq meet_year  round_id  \
# 0   20230103  2023/02/25      3.0     16:30         1      2023         1
# 1   20230103  2023/03/05     10.0     14:00         1      2023         2
# 2   20230103  2023/03/11     13.0     14:00         1      2023         3
# 3   20230103  2023/03/19     23.0     14:00         1      2023         4
# 4   20230103  2023/04/02     30.0     16:30         1      2023         5
# 5   20230103  2023/04/08     31.0     14:00         1      2023         6
# 6        NaN  2023/04/15     37.0     14:00         1      2023         7
# 7   20230103  2023/04/22     43.0     14:00         1      2023         8
# 8   20230103  2023/04/25     49.0     19:30         1      2023         9
# 9        NaN  2023/04/30     59.0     16:30         1      2023        10
# 10       NaN  2023/05/05     63.0     16:30         1      2023        11
# 11       NaN  2023/05/10     71.0     19:30         1      2023        12
# 12       NaN  2023/05/13     75.0     19:00         1      2023        13
# 13       NaN  2023/05/21     83.0     18:00         1      2023        14
# 14       NaN  2023/05/27     85.0     16:30         1      2023        15
# 15       NaN  2023/06/03     92.0     18:00         1      2023        16
# 16       NaN  2023/06/07    100.0     19:00         1      2023        17
# 17       NaN  2023/06/11    108.0     19:00         1      2023        18
# 18       NaN  2023/06/24    109.0     16:30         1      2023        19
# 19  20230103  2023/07/01    116.0     19:00         1      2023        20
# 20  20230103  2023/07/09    126.0     19:00         1      2023        21
# 21  20230103  2023/07/12    130.0     19:30         1      2023        22
# 22  20230103  2023/07/15    133.0     19:00         1      2023        23
# 23  20230103  2023/07/22    142.0     19:30         1      2023        24
# 24  20230103  2023/08/05    147.0     19:00         1      2023        25
# 25  20230103  2023/08/12    151.0     19:00         1      2023        26
# 26  20230103  2023/08/18    157.0     19:30         1      2023        27
# 27       NaN  2023/08/27      NaN     19:30         1      2023        28
# 28       NaN  2023/09/02      NaN     16:30         1      2023        29
# 29       NaN  2023/09/17      NaN     16:30         1      2023        30
# 30       NaN  2023/09/23      NaN     14:00         1      2023        31
# 31       NaN  2023/09/30      NaN     19:00         1      2023        32
# 32       NaN  2023/10/08      NaN     15:00         1      2023        33
#
#    team_id           vs_name
# 0      K02    수원(0) vs (1)광주
# 1      K02    전북(1) vs (1)수원
# 2      K02  수원FC(2) vs (1)수원
# 3      K02    수원(1) vs (3)대전
# 4      K02    수원(1) vs (1)강원
# 5      K02    울산(2) vs (1)수원
# 6      K02    수원(2) vs (3)제주
# 7      K02    서울(3) vs (1)수원
# 8      K02    포항(1) vs (0)수원
# 9      K02    수원(0) vs (1)대구
# 10     K02    인천(0) vs (1)수원
# 11     K02    수원(0) vs (3)전북
# 12     K02    강원(0) vs (2)수원
# 13     K02    수원(2) vs (3)울산
# 14     K02    제주(2) vs (1)수원
# 15     K02  수원(1) vs (2)수원FC
# 16     K02    광주(2) vs (1)수원
# 17     K02    수원(0) vs (0)인천
# 18     K02    수원(0) vs (1)서울
# 19     K02    대구(1) vs (1)수원
# 20     K02    대전(2) vs (2)수원
# 21     K02    수원(1) vs (1)포항
# 22     K02    수원(3) vs (1)울산
# 23     K02    강원(1) vs (2)수원
# 24     K02  수원(0) vs (2)수원FC
# 25     K02    전북(1) vs (1)수원
# 26     K02    수원(1) vs (0)제주
# 27     NaN          광주 vs 수원
# 28     NaN          수원 vs 서울
# 29     NaN          수원 vs 대구
# 30     NaN          대전 vs 수원
# 31     NaN          인천 vs 수원
# 32     NaN          수원 vs 포항
# Object 3:
#    POSITION_NM Player_id  back_no corp_cd  name
# 0           GK  20140081       21     K02   양형모
# 1           GK  20180280       34     K02   박지민
# 2           GK  20200070       99     K02   안찬기
# 3           GK  20210190       31     K02   이성주
# 4           DF  20200315       77     K02   손호준
# 5           DF  20170127       15     K02   고명석
# 6           DF  20220277        5     K02   한호강
# 7           DF  20180324       11     K02   김태환
# 8           DF  20190043        4     K02  불투이스
# 9           DF  20190142       33     K02   박대원
# 10          DF  20160122        3     K02   장호익
# 11          DF  20100131       39     K02   민상기
# 12          DF  20130031       66     K02   김주원
# 13          DF  20160052       23     K02   이기제
# 14          MF  20160099       10     K02   정승원
# 15          MF  20160106       36     K02   명준재
# 16          MF  20160115        7     K02   고승범
# 17          MF  20060013       26     K02   염기훈
# 18          MF  20110032       16     K02   이종성
# 19          MF  20170012        8     K02   최성근
# 20          MF  20140127        6     K02   한석종
# 21          MF  20160004       13     K02   김보경
# 22          MF  20230104       97     K02   바사니
# 23          MF  20230317       81     K02   카즈키
# 24          MF  20170297       12     K02   류승우
# 25          MF  20220186       88     K02   유제호
# 26          FW  20210085       44     K02   뮬리치
# 27          FW  20180006       14     K02   전진우
# 28          FW  20200190       18     K02  아코스티
# 29          FW  20230339       45     K02  웨릭포포
# 30          FW  20220340       29     K02   이상민
# 31          FW  20230098       20     K02   박희준
# 32          FW  20230102       32     K02   서동한
# 33          FW  20230103       37     K02   김주찬
# 34          FW  20170078       17     K02   김경중
# 35          FW  20190256        9     K02   안병준
# 36          FW  20110248       27     K02   고무열
# Object 4:
#    ATT_AREA_ENTER  ATT_AREA_ENTER_AVG  ATT_AREA_ENTER_AVG_Rank  \
# 0               0                   0                        1
#
#    ATT_AREA_ENTER_Rank  Assist_Avg  Assist_Avg_Rank  Assist_Qty  Assist_Rank  \
# 0                    1           0              135           0          135
#
#    CORNER  CORNER_AVG  ...  THROW_INS  THROW_INS_AVG  THROW_INS_AVG_Rank  \
# 0       0           0  ...          0              0                 238
#
#    THROW_INS_Rank  fs_Rank  fs_qty  meet_seq  meet_year  player_id  work_time
# 0             238      207       4         1       2023   20230103        634
#
# [1 rows x 111 columns]
# Object 5:
#    ATT_AREA_PASS  ATT_AREA_PASS_Rank  ATT_AREA_PASS_SUCCESS  \
# 0             63                 149                     52
#
#    ATT_AREA_PASS_SUCCESS_AVG  ATT_AREA_PASS_SUCCESS_AVG_Rank  \
# 0                       3.25                             179
#
#    ATT_AREA_PASS_SUCCESS_Rank  CONTROL_UNDER_PRESSURE  \
# 0                         142                       3
#
#    CONTROL_UNDER_PRESSURE_AVG  CONTROL_UNDER_PRESSURE_AVG_Rank  \
# 0                        0.19                              112
#
#    CONTROL_UNDER_PRESSURE_Rank  ...  SHORT_PASS_SUCCESS_AVG  \
# 0                           84  ...                    6.19
#
#    SHORT_PASS_SUCCESS_AVG_Rank  SHORT_PASS_SUCCESS_Rank  \
# 0                          258                      211
#
#    TRANSVERSE_PASS_SUCCESS  TRANSVERSE_PASS_SUCCESS_AVG  \
# 0                       43                         2.69
#
#    TRANSVERSE_PASS_SUCCESS_AVG_Rank  TRANSVERSE_PASS_SUCCESS_Rank  meet_seq  \
# 0                               282                           236         1
#
#    meet_year  player_id
# 0       2023   20230103
#
# [1 rows x 117 columns]
# Object 6:
#    AIR_CHALG  AIR_CHALG_Rank  AIR_CHALG_WON  AIR_CHALG_WON_AVG  \
# 0         18             218              4               0.25
#
#    AIR_CHALG_WON_AVG_Rank  AIR_CHALG_WON_Rank  AIR_CHALLENGE_PCNT  \
# 0                     288                 242                  22
#
#    AIR_CHALLENGE_PCNT_Rank  BALL_MISS  BALL_MISS_AVG  ...  fs_avg  \
# 0                      285          9           0.56  ...    0.25
#
#    fs_avg_Rank  fs_qty  meet_seq  meet_year  player_id  warn_Rank  warn_avg  \
# 0          255       4         1       2023   20230103        234         0
#
#    warn_avg_Rank  warn_qty
# 0            234         0
#
# [1 rows x 96 columns]
# Object 7:
#    PLAYER_CNT PLAYER_ID ROUND_ID_E ROUND_ID_S TEAM_ID  \
# 0         393  20230103         27          1     K02
#
#                    WORK_TIME
# 0  총출전시간 : 634 / 평균출전시간 : 39
